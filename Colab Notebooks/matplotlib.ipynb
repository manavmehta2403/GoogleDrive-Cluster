# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [2,4,6,8]
plt.plot(x,y)
plt.show()




import matplotlib.pyplot
x=[1,2,3,4]
y=[1,4,9,16]

matplotlib.pyplot.plot(x,y,label= "sq.",color="orange")
matplotlib.pyplot.xlabel("number")
matplotlib.pyplot.ylabel("squares")
matplotlib.pyplot.legend()
matplotlib.pyplot.show()


import matplotlib.pyplot as plt
import numpy

x = numpy.array([1,2,3,4])
y1 = numpy.array([1,4,9,16])
y2 = numpy.array([1,8,27,64])

plt.plot(x,y1,"g--")
plt.hist(x,y2)
plt.title("Multiplier graph")
plt.xlabel("numbers")
plt.ylabel("generator")
plt.legend()
plt.show()


import matplotlib.pyplot as plt
import numpy
x=numpy.array([1,2,3,4])
y1=numpy.array([1,4,9,6])
y2=numpy.array([1,8,27,64])
y3=numpy.array([2,4,6,8])
y4=numpy.array([3,6,9,12])

plt.subplot(2,1,1)
plt.plot(x,y1,"b-",label="sq")
plt.plot(x,y2,"g--",label="cube",)
plt.title("multiple graph")
plt.xlabel("number")
plt.ylabel("generater")
plt.legend()
plt.subplots_adjust(hspace = 0.4, wspace = 0.5)
plt.subplot(2,1,2)
plt.plot(x,y3,label="twice",color="red",linestyle="dashdot")
plt.plot(x,y4,label="thrice",color="black",linestyle='dotted')
plt.title("multiple graph")
plt.xlabel("number")
plt.ylabel("generater")
plt.legend()
plt.show()        
         
               

import numpy #for arange to loop over the float values
import matplotlib.pyplot as plt #to plot the graphs

x = [1,2,3,4,5,6,7]
y = [2,4,6,8,10,12,14]
z = [14,12,10,8,6,4,2]

plt.plot(x,y,"y*--",x,z,"c+:")
plt.legend(["forward twice", "reverse twice"])
plt.show()

plt.plot(x,y,color="yellow",marker="*",linestyle="dashed",label="forward twice")
plt.plot(x,z,c="c",marker="+",linestyle="dotted",label="reverse twice")
plt.legend()

plt.show()

plt.title()
plt.xlabel()
plt.ylabe()



import numpy
import matplotlib.pyplot as plt 
randnums= numpy.random.randint(low=0, high=2, size=(10,20))
print (randnums)
firing_Rate=100
time_Resolution=1/1000 
time_Duration=10
fr=firing_Rate*time_Resolution
print (fr)
spikes=1
no_spikes=0
spikelist=np.zeros([10, 20])



for i in range(0, randnums.shape[0]):
    for j in range(0, randnums.shape[1]):
      if(randnums[i,j]>fr):
        spikelist[i,j] = spikes
    else:
      spikelist[i,j] = no_spikes



plt.plot(spikelist)
print(spikelist)
plt.show()


import matplotlib.pyplot as plot

import numpy as np

 



 

 

neuralData = 2 * np.random.random_sample((10, 20)) + 0

print(neuralData)



plot.eventplot(neuralData)     


plot.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 x = [1,2,3,4]
#       4 y = [2,4,6,8]
#
# ModuleNotFoundError: No module named 'matplotlib'
